# %% [markdown]
# ## polymorphism => poly + morphism => many + form

# %% [markdown]
# ## mthod overloading and method overriding

# %% [markdown]
# # ex =

# %%
1+2
# Out:
# 3

# %%
"1"+"2"
# Out:
# '12'

# %%
class parent:
    def info(eid):
        print("this is the parent class")

class child(parent):
    def info(eid):
        print("this is child claas")

# %%
c1=child()
c1.info()
# Out:
# this is child claas

# %%
class parent:
    def info(eid):
        print("this is the parent class")

class child(parent):
    def cinfo(eid):
        print("this is child claas")

# %%
c1=child()
c1.info()
# Out:
# this is the parent class

# %% [markdown]
# ## pyhon does not support overloading method
# ## it is follow overriding and oprater overloading

# %%
class raj:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2

    def __repr__(self):
        return f"raj class has {self.num1} {self.num2}"

r1=raj(10,20)
print(r1)
# Out:
# raj class has 10 20

# %%
r2=raj(35,55)

# %%
class raj:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2

    def __repr__(self):
        return f"raj class has {self.num1} {self.num2}"
# self=r1 and x=r2
    def __add__(self,x):
        print("hey")

r1=raj(10,20)
r2=raj(35,55)
r1+r2
# r1 __add(r2)
# Out:
# hey

# %%
class raj:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2

    def __repr__(self):
        return f"raj class has {self.num1} {self.num2}"

r1=raj(10,20)
r1
# Out:
# raj class has 10 20

# %%
class raj:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2

    def __repr__(self):
        return f"raj class has {self.num1} {self.num2}"
# self=r1 and obj=r2
    def __add__(self,obj):
        x1=self.num1+obj.num1
        return x1

r1=raj(10,20)
r2=raj(35,55)
r1+r2
# Out:
# 45

# %%
class grater:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2

    def __repr__(self):
        return f"raj class has {self.num1} {self.num2}"
# self=r1 and obj=r2
    def __gt__(self,obj):
        if(self.num1>obj.num1):
        
            return "true"

        else:
        
        
            return "false" 

r1=grater(10,20)
r2=grater(5,25)

#r1  > r2
r1.__gt__(r2)
# Out:
# 'true'
