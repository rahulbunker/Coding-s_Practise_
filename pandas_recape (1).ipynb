# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\pandas\\customer.csv")

# %%
df1
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
df.head(5)
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
df.sample(6)
# Out:
#     age  gender review education purchased
# 16   59    Male   Poor        UG       Yes
# 26   53  Female   Poor        PG        No
# 22   18  Female   Poor        PG       Yes
# 28   48    Male   Poor    School        No
# 25   57  Female   Good    School        No
# 17   22  Female   Poor        UG       Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        50 non-null     int64
#  1   gender     50 non-null     object
#  2   review     50 non-null     object
#  3   education  50 non-null     object
#  4   purchased  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#              age
# count  50.000000
# mean   54.160000
# std    25.658161
# min    15.000000
# 25%    30.250000
# 50%    57.000000
# 75%    74.000000
# max    98.000000

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\pandas\\placement2.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
df1 = df1.iloc[5:,2:]

# %%
df1.head(5)
# Out:
#     review education purchased
# 5  Average    School       Yes
# 6     Good    School        No
# 7     Poor    School       Yes
# 8  Average        UG        No
# 9     Good        UG       Yes

# %%
plt.scatter(x=df["cgpa"],y=df["package"])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split (x,y, test_size =0.2 , stratify =y , random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 x_train, x_test , y_train , y_test = train_test_split (x,y, test_size =0.2 , stratify =y , random_state = 42)
#
# NameError: name 'x' is not defined

# %%
x = df.iloc[:,0:2]
x
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x)

# %%
x_train
# Out:
# array([[-0.094213  ,  0.38258449],
#        [-1.75348666, -1.472722  ],
#        [ 0.77760876,  0.36808991],
#        [ 0.40263166,  0.97686235],
#        [-0.04734086,  0.83191653],
#        [ 0.84322975, -0.00876922],
#        [-0.24420384, -0.57405792],
#        [-0.22545498, -0.7479929 ],
#        [-0.8441672 , -0.9944008 ],
#        [ 1.23695571,  0.74494904],
#        [-1.56599811, -1.64665698],
#        [-0.35669697, -0.57405792],
#        [ 1.82754464,  0.94787319],
#        [-0.05671529, -0.15371504],
#        [ 0.69323891,  0.6144978 ],
#        [ 0.24326639,  0.33910075],
#        [-0.14108513, -0.93642247],
#        [-1.50975155, -1.3132816 ],
#        [-0.04734086, -0.0232638 ],
#        [ 0.45887823, -0.24068253],
#        [ 0.27138968,  0.23763867],
#        [-0.13171071, -0.09573671],
#        [-0.79729506, -1.00889538],
#        [-0.75042292, -0.7479929 ],
#        [-0.43169239, -0.41461752],
#        [ 0.27138968,  0.94787319],
#        [ 1.23695571,  0.6144978 ],
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_tarin =scaler.fit_transform(x)

# %%
mylist=[1,2,3]

# %%
mylist
# Out:
# [1, 2, 3]

# %%
mylist.append("hello")

# %%
mylist
# Out:
# [1, 2, 3, 'hello']

# %%
mylist.extend("hey")
mylist
# Out:
# [1, 2, 3, 'hello', 'h', 'e', 'y']

# %%
mylist.pop(2)
mylist
# Out:
# [1, 2, 'hello', 'h', 'e', 'y']

# %%
mylist.pop(0)
mylist
# Out:
# [2, 'hello', 'h', 'e', 'y']

# %%
mylist.remove("hello")
mylist
# Out:
# [2, 'h', 'e', 'y']

# %%
del mylist[-1]
mylist
# Out:
# [2, 'h', 'e']

# %%
for i in mylist:
    if( type(i) is int):
        print(i)
# Out:
# 2

# %%
for i in mylist:
    if(type(i) is not int):
        print(i)
# Out:
# h
# e

# %%
marks = [10,20,30,40]
marks_new =[]
for i in marks:
    a=i+2
    marks_new.append(a)

marks_new
# Out:
# [12, 22, 32, 42]

# %%
marks = [10,20,30,40]
marks_new =[ i +5 for i in marks]

# %%
marks_new
# Out:
# [15, 25, 35, 45]

# %%
q = []
for i in range(10):
    if (i%2==0):
        q.append(i)

q
# Out:
# [0, 2, 4, 6, 8]

# %%
q = [i**2 for i in range(10)]

# %%
q
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
type(q)
# Out:
# list

# %%
q = {i**2 for i in range(10)}
q
# Out:
# {0, 1, 4, 9, 16, 25, 36, 49, 64, 81}

# %%
type(q)
# Out:
# set

# %%
names =["rahul" ,"jatin" ,"gopal"]
first =[i[0] for i in names]
first
# Out:
# ['r', 'j', 'g']

# %%
ss = {1:1 , 2:2 , 3:3}
sss = {i : i**3 for i in ss}
sss
# Out:
# {1: 1, 2: 8, 3: 27}

# %%
651
# Out:
# 651

# %%
a={
    "roll no":[1,2,3],
    "name":["rahul","jatin","raj"]
}

# %%
b=pd.DataFrame(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 b=pd.DataFrame(a)
#
# NameError: name 'pd' is not defined

# %%
b
