# %%
f = open("file.txt" ,"r")
data = f.read()
print(data)
print(type(data))
f.close()
# Out:
# mr hello to learn form iiit lucknow
# <class 'str'>

# %%
f = open("file.txt" ,"rt")
data = f.read()
print(data)
print(type(data))
f.close()
# Out:
# mr hello to learn form iiit lucknow
# <class 'str'>

# %%
f = open("file.txt" , "r")
line1 = f.readline()
print(line1)
line2=f.readline()
print(line2)
f.close()
# Out:
# mr hello to learn form iiit lucknow

# %%
f = open("file.txt" , "r")
data = f.read(5)
print(data)
f.close()
# Out:
# mr he

# %%
f = open("file.txt" , "r")
f.read()
line1 = f.readline()
print(line1)
line2 = f.readline()
print(line2)
f.close()

# %%
f = open("file.txt" , "w")
f.write("i want to learn data science")
f.close()

# %%
f = open("file.txt" , "w")
f.write("\ni want to learn form iiit lucknow")
f.close()

# %%
f = open("sample.txt" , "a")
data = f.write("helo mr.") 
f.close()

# %%
f = open("sample.txt" , "r+")
f.write("i want to learn python")
f.close()

# %%
f = open("sample.txt" , "r+")
f.write("mr mbjkbhello")
print(f.read())
f.close()
# Out:
# rn pythonhelo mr.

# %%
with open("demo.txt","a+") as f:
    data = f.read()

# %%
with open("file.txt","r") as f:
    data = f.read()
    print(data)
# Out:
# i want to learn form iiit lucknow

# %%
import os
os.remove("demo.txt")

# %%
f.close()

# %%
with open("file.txt","w" ) as f:
    f.write("hi everyone\nwe are learning file \nusinf java \n")
    f.write("i like programming in java")

# %%
with open("file.txt" ,"r" )as f:
    data = f.read()

new_data = data.replace("java","python")
print(new_data)

with open("q1.txt","w") as f:
    f.write(new_data)
# Out:
# hi everyone
# we are learning file
# usinf python
# i like programming in python
